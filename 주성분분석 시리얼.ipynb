# %%
import pandas as pd
cereals_df = pd.read_csv("D:/dmba/Cereals.csv")

# %%
cereals_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100%_Bran   N    C        70        4    1     130   10.0
# 1           100%_Natural_Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran_with_Extra_Fiber   K    C        50        4    0     140   14.0
# 4              Almond_Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat_Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties_Honey_Gold   G    C       110        2    1     200    1.0
#
# ...

# %%
# 각 양적 변수의 평균, 중앙값, 최솟값, 최댓값, 표준편차
pd.DataFrame({'mean': cereals_df.mean(), 'median': cereals_df.median(), 'min':cereals_df.min(), 'max':cereals_df.max(), 'std': cereals_df.std()})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[78], line 2
#       1 # 각 양적 변수의 평균, 중앙값, 최솟값, 최댓값, 표준편차
# ----> 2 pd.DataFrame({'mean': cereals_df.mean(), 'median': cereals_df.median(), 'min':cereals_df.min(), 'max':cereals_df.max(), 'std': cereals_df.std()})
#
# File c:\Users\USER\anaconda3\envs\Pytorch\lib\site-packages\pandas\core\frame.py:11680, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11672 @doc(make_doc("mean", ndim=2))
#   11673 def mean(
#   11674     self,
#    (...)
#   11678     **kwargs,
#   11679 ):
# > 11680     result = super().mean(axis, skipna, numeric_only, **kwargs)
#   11681     if isinstance(result, Series):
#   11682         result = result.__finalize__(self, method="mean")
#
# ...

# %%
# 각 양적 변수에 대한 히스토그램 그리기
exclude_ = ('mfr', 'type', 'shelf', 'name', 'cups')

columns_ = [s for s in cereals_df.columns if s not in exclude_ ]
print(columns_)

ax = cereals_df.calories.hist()
ax.set_xlabel('calories')
ax.set_ylabel('count')
# Out:
# ['calories', 'protein', 'fat', 'sodium', 'fiber', 'carbo', 'sugars', 'potass', 'vitamins', 'weight', 'rating']
# Text(0, 0.5, 'count')

# %%
ax1 = cereals_df.protein.hist()
ax1.set_xlabel('protein')
ax1.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ax2 = cereals_df.fat.hist()
ax2.set_xlabel('fat')
ax2.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ax3 = cereals_df.sodium.hist()
ax3.set_xlabel('sodium')
ax3.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ax = cereals_df.boxplot(column='calories')
ax.set_ylabel('Calories')
# Out:
# Text(0, 0.5, 'Calories')

# %%
ax = cereals_df.boxplot(column='protein')
ax.set_ylabel('protein')
# Out:
# Text(0, 0.5, 'protein')

# %%
ax = cereals_df.boxplot(column='fat')
ax.set_ylabel('fat')
# Out:
# Text(0, 0.5, 'fat')

# %%
ax = cereals_df.boxplot(column='sodium')
ax.set_ylabel('sodium')
# Out:
# Text(0, 0.5, 'sodium')

# %%
#저온용과 고온용 시리얼에 함유된 칼로리를 비교하기 위해 박스 플롯을 나란히 그리기
import pandas as pd
cereals_df = pd.read_csv("D:/dmba/Cereals.csv")

cereals_df.type = [1 if cereals_df.type[i] == "C" else 0 for i in range(len(cereals_df))]

cereals_df.boxplot(column = 'calories', by='type')

print(cereals_df.type)
# Out:
# 0     1
# 1     1
# 2     1
# 3     1
# 4     1
#      ..
# 72    1
# 73    1
# 74    1
# 75    1
# 76    1
# Name: type, Length: 77, dtype: int64

# %%
#시리얼이 놓인 진열대 높이에 따른 소비자 평점의 박스 플롯

import pandas as pd
cereals_df = pd.read_csv("D:/dmba/Cereals.csv")

cereals_df.boxplot(column = 'rating', by='shelf')
# Out:
# <Axes: title={'center': 'rating'}, xlabel='shelf'>

# %%
df = cereals_df.drop(['mfr', 'type', 'name'], axis=1)
df.corr().round(2)
# Out:
#           calories  protein   fat  sodium  fiber  carbo  sugars  potass  \
# calories      1.00     0.02  0.50    0.30  -0.29   0.26    0.57   -0.07
# protein       0.02     1.00  0.21   -0.05   0.50  -0.03   -0.29    0.56
# fat           0.50     0.21  1.00   -0.01   0.02  -0.30    0.30    0.20
# sodium        0.30    -0.05 -0.01    1.00  -0.07   0.30    0.06   -0.04
# fiber        -0.29     0.50  0.02   -0.07   1.00  -0.38   -0.14    0.91
# carbo         0.26    -0.03 -0.30    0.30  -0.38   1.00   -0.47   -0.37
# sugars        0.57    -0.29  0.30    0.06  -0.14  -0.47    1.00    0.00
# potass       -0.07     0.56  0.20   -0.04   0.91  -0.37    0.00    1.00
# vitamins      0.27     0.01 -0.03    0.36  -0.03   0.22    0.10   -0.01
# shelf         0.10     0.13  0.26   -0.07   0.30  -0.19    0.07    0.39
# weight        0.70     0.22  0.21    0.31   0.25   0.14    0.46    0.42
# cups          0.09    -0.24 -0.18    0.12  -0.51   0.37   -0.05   -0.50
# ...

# %%
# 높은 음의 상관관계를 보이는 쌍은 평점과 칼로리 입니다. 
# 이를 바탕으로 의미있는 상관관계를 가진 변수들로 축소할 수 있습니다. 
# 변동의 관점에서 정규화는 모든 변수에 동등한 중요성을 부여할 수 있습니다. 
# 첫번째 주성분은 데이터의 변동성이 가장 큰 방향을 나타내고 이떼 이 직선의 분산은 최대가 된다.

# %%
import pandas as pd
toyota = pd.read_csv("D:/dmba/ToyotaCorolla.csv")

toyota.Fuel_Type = toyota.Fuel_Type.astype('category')
toyota.Fuel_Type.cat.categories

# 범주형 변수로는 나이, 월, 연도 등이 있습니다.
# 범주의 개수보다 하나 적게 가변수를 만듭니다.
# Out:
# Index(['CNG', 'Diesel', 'Petrol'], dtype='object')

# %%
toyota.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Color', 'Automatic', 'CC', 'Doors',
#        'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee',
#        'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2',
#        'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player',
#        'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio',
#        'Mistlamps', 'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
#        'Radio_cassette', 'Parking_Assistant', 'Tow_Bar'],
#       dtype='object')

# %%
toyota.Fuel_Type.dtype
# Out:
# CategoricalDtype(categories=['CNG', 'Diesel', 'Petrol'], ordered=False, categories_dtype=object)

# %%
toyota = pd.get_dummies(toyota, prefix_sep='_', drop_first=True)
toyota.columns
# Out:
# Index(['Id', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM', 'HP',
#        'Met_Color', 'Automatic', 'CC',
#        ...
#        'Fuel_Type_Petrol', 'Color_Black', 'Color_Blue', 'Color_Green',
#        'Color_Grey', 'Color_Red', 'Color_Silver', 'Color_Violet',
#        'Color_White', 'Color_Yellow'],
#       dtype='object', length=365)

# %%
toyota.loc[:, 'Fuel_Type_CNG':'Fuel_Type_Petrol']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\USER\anaconda3\envs\Pytorch\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Fuel_Type_CNG'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %%
import pandas as pd
from sklearn.decomposition import PCA
import numpy as np

wine_df = pd.read_csv("D:/dmba/Wine.csv")
wine_df = wine_df.drop(columns=['Type'])
pcs = PCA()
pcs.fit(wine_df.dropna(axis=0))
pcsSummary_df = pd.DataFrame({'Standard deviation':np.sqrt(pcs.explained_variance_), 
                              'Proportion of variance': pcs.explained_variance_ratio_,
                              'Cumulative Proportion':np.cumsum(pcs.explained_variance_ratio_)})
pcsSummary_df
# Out:
#     Standard deviation  Proportion of variance  Cumulative Proportion
# 0           314.963156            9.980912e-01               0.998091
# 1            13.135268            1.735916e-03               0.999827
# 2             3.072151            9.495896e-05               0.999922
# 3             2.234095            5.021736e-05               0.999972
# 4             1.108533            1.236368e-05               0.999985
# 5             0.917095            8.462130e-06               0.999993
# 6             0.528179            2.806815e-06               0.999996
# 7             0.389077            1.523081e-06               0.999997
# 8             0.334809            1.127830e-06               0.999999
# 9             0.267773            7.214158e-07               0.999999
# 10            0.193845            3.780603e-07               1.000000
# 11            0.145163            2.120138e-07               1.000000
# ...

# %%
pcsSummary_df = pcsSummary_df.transpose()
pcsSummary_df = ['PC{}'.format(i) for i in range(1, len(pcsSummary_df.columns) + 1)]
pcsSummary_df
# Out:
# ['PC1',
#  'PC2',
#  'PC3',
#  'PC4',
#  'PC5',
#  'PC6',
#  'PC7',
#  'PC8',
#  'PC9',
#  'PC10',
#  'PC11',
#  'PC12',
#  'PC13']

# %%
pcsComponents_df = pd.DataFrame(pcs.components_.transpose(), columns=pcsSummary_df, index=wine_df.columns)
pcsComponents_df.iloc[:, :5]
# Out:
#                            PC1       PC2       PC3       PC4       PC5
# Alcohol               0.001659  0.001203 -0.016874 -0.141447  0.020337
# Malic_Acid           -0.000681  0.002155 -0.122003 -0.160390 -0.612883
# Ash                   0.000195  0.004594 -0.051987  0.009773  0.020176
# Ash_Alcalinity       -0.004671  0.026450 -0.938593  0.330965  0.064352
# Magnesium             0.017868  0.999344  0.029780  0.005394 -0.006149
# Total_Phenols         0.000990  0.000878  0.040485  0.074585  0.315245
# Flavanoids            0.001567 -0.000052  0.085443  0.169087  0.524761
# Nonflavanoid_Phenols -0.000123 -0.001354 -0.013511 -0.010806 -0.029648
# Proanthocyanins       0.000601  0.005004  0.024659  0.050121  0.251183
# Color_Intensity       0.002327  0.015100 -0.291398 -0.878894  0.331747
# Hue                   0.000171 -0.000763  0.025978  0.060035  0.051524
# OD280_OD315           0.000705 -0.003495  0.070324  0.178200  0.260639
# ...

# %%
# 데이터의 변동이 가장 크기 때문입니다. 
# 데이터의 표준화 및 정규화가 필요하지만 표준화를 진행하지 않고 주성분을 구했습니다. 
# 단위 gram 으로 같기 때문에 변수들을 분산이 1이 되도록 데이터의 스케일을 재조정하지 않는 것이 최선일 수 있습니다.

# %%
import pandas as pd

uni_rank = pd.read_csv("D:/dmba/Universities.csv")

uni_rank.columns
# Out:
# Index(['College Name', 'State', 'Public (1)/ Private (2)', '# appli. rec'd',
#        '# appl. accepted', '# new stud. enrolled', '% new stud. from top 10%',
#        '% new stud. from top 25%', '# FT undergrad', '# PT undergrad',
#        'in-state tuition', 'out-of-state tuition', 'room', 'board',
#        'add. fees', 'estim. book costs', 'estim. personal $', '% fac. w/PHD',
#        'stud./fac. ratio', 'Graduation rate'],
#       dtype='object')

# %%
uni_rank
# Out:
#                            College Name State  Public (1)/ Private (2)  \
# 0             Alaska Pacific University    AK                        2
# 1     University of Alaska at Fairbanks    AK                        1
# 2        University of Alaska Southeast    AK                        1
# 3     University of Alaska at Anchorage    AK                        1
# 4           Alabama Agri. & Mech. Univ.    AL                        1
# ...                                 ...   ...                      ...
# 1297        West Virginia State College    WV                        1
# 1298           West Virginia University    WV                        1
# 1299     West Virginia Wesleyan College    WV                        2
# 1300            Wheeling Jesuit College    WV                        2
# 1301              University of Wyoming    WY                        1
#
#       # appli. rec'd  # appl. accepted  # new stud. enrolled  \
# ...

# %%
uni_rank = pd.DataFrame(uni_rank.iloc[:, 3:].dropna(axis=0))
uni_rank
# Out:
#       # appli. rec'd  # appl. accepted  # new stud. enrolled  \
# 0              193.0             146.0                  55.0
# 2              146.0             117.0                  89.0
# 9              805.0             588.0                 287.0
# 11             608.0             520.0                 127.0
# 21            4414.0            1500.0                 335.0
# ...              ...               ...                   ...
# 1274          5729.0            4520.0                1957.0
# 1283           152.0             128.0                  75.0
# 1284           582.0             498.0                 172.0
# 1291          4226.0            3666.0                2007.0
# 1301          2029.0            1516.0                1073.0
#
#       % new stud. from top 10%  % new stud. from top 25%  # FT undergrad  \
# 0                         16.0                      44.0           249.0
# 2                          4.0                      24.0           492.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

ScalerX = StandardScaler()
ScalerX.fit(uni_rank)
X_std = ScalerX.transform(uni_rank)

pca = PCA()
pca.fit(X_std)

pcaSummary_df = pd.DataFrame({'Standard deviation': np.sqrt(pca.explained_variance_), 
                              'Proportion of variance': pca.explained_variance_ratio_,
                              'Cumulative proportion':np.cumsum(pca.explained_variance_ratio_)})
pcaSummary_df = pcaSummary_df.transpose()
pcaSummary_df.columns = ['PC{}'.format(i) for i in range(1, len(pcaSummary_df.columns) + 1)]

pcaComponents_df = pd.DataFrame(pca.components_.transpose(), columns=pcaSummary_df.columns, index = uni_rank.columns)
pcaComponents_df
# Out:
#                                PC1       PC2       PC3       PC4       PC5  \
# # appli. rec'd            0.078361  0.420164 -0.031982  0.072621 -0.016694
# # appl. accepted          0.023659  0.434471 -0.031423  0.118128 -0.089073
# # new stud. enrolled     -0.028802  0.445556 -0.038651 -0.031466 -0.075981
# % new stud. from top 10%  0.354028  0.093547 -0.120129 -0.372457  0.162260
# % new stud. from top 25%  0.340496  0.118396 -0.142720 -0.385565  0.158187
# # FT undergrad           -0.049586  0.443583 -0.004012 -0.056459 -0.094781
# # PT undergrad           -0.106380  0.287700  0.265769  0.053495 -0.343681
# in-state tuition          0.379389 -0.150248  0.084350  0.041064 -0.172639
# out-of-state tuition      0.402555 -0.048728  0.051577  0.077658 -0.158499
# room                      0.273165  0.052271  0.250578  0.454416 -0.004482
# board                     0.290437  0.010051  0.252096  0.301620 -0.199067
# ...

# %%
# 변수들이 다른 단위로 측정되어 변수 간의 변동성을 비교하는 방법이 불분명하기 때문에 일반적으로 정규화 하는 것이 바람직합니다.
